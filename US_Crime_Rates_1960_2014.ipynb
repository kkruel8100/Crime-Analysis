# %%
# Import required libraries and dependencies
import pandas as pd
import numpy as np
from prophet import Prophet
import datetime as dt
import scipy.stats as sts
import hvplot.pandas
#from methods.dataframe_methods import clean_columns

# %% [markdown]
# US crime rates 1960-2014

# %%
# Read the CSV file into a `pandas` DataFrame - US Crime Rates 1960-2014 Data Set
us_crime_1960_2014_df = pd.read_csv("resources/US_Crime_Rates_1960_2014.csv", low_memory=False)

# Update column names and set max columns
us_crime_1960_2014_df.columns = us_crime_1960_2014_df.columns.str.lower()
us_crime_1960_2014_df.columns = us_crime_1960_2014_df.columns.str.replace(' ', '_')
pd.set_option("display.max_columns", None)

# Display df head and info
display(us_crime_1960_2014_df.head())
display(us_crime_1960_2014_df.info())
# Out:
#    year  population    total  violent  property  murder  forcible_rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    robbery  aggravated_assault  burglary  larceny_theft  vehicle_theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
# ...

# %%
# Create copy
us_crime_1960_2014_df_copy = us_crime_1960_2014_df.copy()

# %%
#cleaned_crime_1960_2014_copy = clean_columns(us_crime_1960_2014_df_copy)

# %%
# group crimes by type
violent_crimes = us_crime_1960_2014_df_copy[['year', 'murder', 'forcible_rape', 'robbery', 'aggravated_assault',]]
violent_crimes.head()
# Out:
#    year  violent  murder  forcible_rape  robbery  aggravated_assault
# 0  1960   288460    9110          17190   107840              154320
# 1  1961   289390    8740          17220   106670              156760
# 2  1962   301510    8530          17550   110860              164570
# 3  1963   316970    8640          17650   116470              174210
# 4  1964   364220    9360          21420   130390              203050

# %%
# rename 'violent' column
violent_crimes = violent_crimes.rename(columns={'violent': 'total violent crimes'})
violent_crimes.head()
# Out:
#    year  total violent crimes  murder  forcible_rape  robbery  \
# 0  1960                288460    9110          17190   107840
# 1  1961                289390    8740          17220   106670
# 2  1962                301510    8530          17550   110860
# 3  1963                316970    8640          17650   116470
# 4  1964                364220    9360          21420   130390
#
#    aggravated_assault
# 0              154320
# 1              156760
# 2              164570
# 3              174210
# 4              203050

# %%
#Then look at creating some visuals, maybe some line charts by year and type of offense. 
# use .plot() to create a line chart of the data by year and type of offense.
#us_crime_1960_2014_df_copy.plot(x='year', y='violent', title='Violent Crime by Year', figsize=(10, 5))
#violent_crimes.hvplot()
violent_crimes.hvplot(x='year', title = 'Violent Crime by Year')
# Out:
# :NdOverlay   [Variable]
#    :Curve   [year]   (value)

# %%
# One thing I think is confusing about that data set.  Is the definition of the columns? violent + property doesn’t 
# equal total if I try adding up the columns that i think are “violent”, they don’t add up to the violent column.

# %%
# I also transformed inflation/unemployment into something with a year column.  
#So you could do an hvplot similar to what I did.  That dataset might really look nice next to the other two 
#because of the year span.  And we might be able to do some correlations.
