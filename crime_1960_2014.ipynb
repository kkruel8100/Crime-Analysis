# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from prophet import Prophet
import numpy as np
import matplotlib.pyplot as plt

# %%
# Import methods 
import sys
sys.path.append("..")
from methods.dataframe_methods import clean_columns

# %%
# Set column display options
pd.set_option("display.max_columns", None)

# %% [markdown]
# US crime rates 1960-2014

# %%
# Read the CSV file into a `pandas` DataFrame - US Crime Rates 1960-2014 Data Set
us_crime_1960_2014_file = "https://raw.githubusercontent.com/kkruel8100/Crime-Analysis/main/resources/US_Crime_Rates_1960_2014.csv"
us_crime_1960_2014_df = pd.read_csv(us_crime_1960_2014_file, low_memory=False)

# Create copy
us_crime_1960_2014_df_copy = us_crime_1960_2014_df.copy()

# Clean columns
cleaned_crime_1960_2014_copy = clean_columns(us_crime_1960_2014_df_copy)
cleaned_crime_1960_2014_copy.head()

# Rename columns
cleaned_crime_1960_2014_copy = cleaned_crime_1960_2014_copy.rename(columns={"violent": "total_violent", "property": "total_nonviolent"})

# Display df head and info
display(cleaned_crime_1960_2014_copy.head())
display(cleaned_crime_1960_2014_copy.info())
# Out:
#    year  population    total  total_violent  total_nonviolent  murder  \
# 0  1960   179323175  3384200         288460           3095700    9110
# 1  1961   182992000  3488000         289390           3198600    8740
# 2  1962   185771000  3752200         301510           3450700    8530
# 3  1963   188483000  4109500         316970           3792500    8640
# 4  1964   191141000  4564600         364220           4200400    9360
#
#    forcible_rape  robbery  aggravated_assault  burglary  larceny_theft  \
# 0          17190   107840              154320    912100        1855400
# 1          17220   106670              156760    949600        1913000
# 2          17550   110860              164570    994300        2089600
# 3          17650   116470              174210   1086400        2297800
# 4          21420   130390              203050   1213200        2514400
#
#    vehicle_theft
# 0         328200
# 1         336000
# 2         366800
# 3         408300
# 4         472800
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   year                55 non-null     int64
#  1   population          55 non-null     int64
#  2   total               55 non-null     int64
#  3   total_violent       55 non-null     int64
#  4   total_nonviolent    55 non-null     int64
#  5   murder              55 non-null     int64
#  6   forcible_rape       55 non-null     int64
#  7   robbery             55 non-null     int64
#  8   aggravated_assault  55 non-null     int64
#  9   burglary            55 non-null     int64
#  10  larceny_theft       55 non-null     int64
#  11  vehicle_theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB
# None

# %%
# Reset index to year
crime_rates_df = cleaned_crime_1960_2014_copy.set_index('year')
crime_rates_df.tail()
# Out:
#       population     total  total_violent  total_nonviolent  murder  \
# year
# 2010   309330219  10363873        1251248           9112625   14772
# 2011   311587816  10258774        1206031           9052743   14661
# 2012   313873685  10219059        1217067           9001992   14866
# 2013   316497531   9850445        1199684           8650761   14319
# 2014   318857056   9475816        1197987           8277829   14249
#
#       forcible_rape  robbery  aggravated_assault  burglary  larceny_theft  \
# year
# 2010          85593   369089              781844   2168457        6204601
# 2011          84175   354772              752423   2185140        6151095
# 2012          85141   355051              762009   2109932        6168874
# 2013          82109   345095              726575   1931835        6018632
# 2014          84041   325802              741291   1729806        5858496
#
#       vehicle_theft
# year
# 2010         739565
# 2011         716508
# 2012         723186
# 2013         700294
# 2014         689527

# %%
# Convert values into millions
crime_rates_df = crime_rates_df / 1000000
crime_rates_df.head()
# Out:
#       population   total  total_violent  total_nonviolent   murder  \
# year
# 1960  179.323175  3.3842        0.28846            3.0957  0.00911
# 1961  182.992000  3.4880        0.28939            3.1986  0.00874
# 1962  185.771000  3.7522        0.30151            3.4507  0.00853
# 1963  188.483000  4.1095        0.31697            3.7925  0.00864
# 1964  191.141000  4.5646        0.36422            4.2004  0.00936
#
#       forcible_rape  robbery  aggravated_assault  burglary  larceny_theft  \
# year
# 1960        0.01719  0.10784             0.15432    0.9121         1.8554
# 1961        0.01722  0.10667             0.15676    0.9496         1.9130
# 1962        0.01755  0.11086             0.16457    0.9943         2.0896
# 1963        0.01765  0.11647             0.17421    1.0864         2.2978
# 1964        0.02142  0.13039             0.20305    1.2132         2.5144
#
#       vehicle_theft
# year
# 1960         0.3282
# 1961         0.3360
# 1962         0.3668
# 1963         0.4083
# 1964         0.4728

# %%
# Remove population, violent, and property crime columns.
crime_rates = crime_rates_df.drop(columns=["population", "total_violent", "total_nonviolent"])
crime_rates.head()
# Out:
#        total   murder  forcible_rape  robbery  aggravated_assault  burglary  \
# year
# 1960  3.3842  0.00911        0.01719  0.10784             0.15432    0.9121
# 1961  3.4880  0.00874        0.01722  0.10667             0.15676    0.9496
# 1962  3.7522  0.00853        0.01755  0.11086             0.16457    0.9943
# 1963  4.1095  0.00864        0.01765  0.11647             0.17421    1.0864
# 1964  4.5646  0.00936        0.02142  0.13039             0.20305    1.2132
#
#       larceny_theft  vehicle_theft
# year
# 1960         1.8554         0.3282
# 1961         1.9130         0.3360
# 1962         2.0896         0.3668
# 1963         2.2978         0.4083
# 1964         2.5144         0.4728

# %%
# Plot all crimes
crime_rates_plot = crime_rates.hvplot.line(
    title = "US Crime Rates 1960-2014",
    xlabel = "Year",
    ylabel = "Number of Crimes (in Millions)",
    width = 1000,
    height = 500,
    grid = True
)

# Display plot
crime_rates_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [year]   (value)

# %%
# Group crimes by non-violent 
nonviolent_crimes = crime_rates_df[["total_nonviolent", "burglary", "larceny_theft", "vehicle_theft"]]
nonviolent_crimes.head()

# Show nonviolent_crimes
nonviolent_crimes.head()
# Out:
#       total_nonviolent  burglary  larceny_theft  vehicle_theft
# year
# 1960            3.0957    0.9121         1.8554         0.3282
# 1961            3.1986    0.9496         1.9130         0.3360
# 1962            3.4507    0.9943         2.0896         0.3668
# 1963            3.7925    1.0864         2.2978         0.4083
# 1964            4.2004    1.2132         2.5144         0.4728

# %%
# Plot non-violent crimes
nonviolent_crimes_plot = nonviolent_crimes.hvplot.line(
    title="Non-Violent Crimes 1960-2014",
    xlabel="Year",
    ylabel="Number of Crimes (in Millions)",
    width=1000,
    height=400,
    grid=True
)

# Display plot
nonviolent_crimes_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [year]   (value)

# %%
# Slice the data to show only total non-violent crimes
total_nonviolent_crimes = crime_rates_df[["total_nonviolent"]]
total_nonviolent_crimes.head()
# Out:
#       total_nonviolent
# year
# 1960            3.0957
# 1961            3.1986
# 1962            3.4507
# 1963            3.7925
# 1964            4.2004

# %%
# Plot only total non-violent crimes
total_nonviolent_crimes_plot = total_nonviolent_crimes.hvplot.line(
    title="Total Non-Violent Crimes 1960-2014",
    x='year',
    xlabel="Year",
    ylabel="Number of Crime (in Millions)",
    width=1000,
    height=400,
    grid=True
)

# Display plot
total_nonviolent_crimes_plot
# Out:
# :Curve   [year]   (total_nonviolent)

# %%
# Group crimes by violent
violent_crimes = crime_rates_df[['total_violent', 'murder', 'forcible_rape', 'robbery', 'aggravated_assault',]]
violent_crimes.head()
# Out:
#       total_violent   murder  forcible_rape  robbery  aggravated_assault
# year
# 1960        0.28846  0.00911        0.01719  0.10784             0.15432
# 1961        0.28939  0.00874        0.01722  0.10667             0.15676
# 1962        0.30151  0.00853        0.01755  0.11086             0.16457
# 1963        0.31697  0.00864        0.01765  0.11647             0.17421
# 1964        0.36422  0.00936        0.02142  0.13039             0.20305

# %%
# Create visual for violent crimes 
violent_crimes_plot = violent_crimes.hvplot( 
    title="Violent Crimes 1960-2014",
    x='year',
    xlabel="Year",
    ylabel="Number of Crimes (in Millions)",
    width=1000,
    height=400,
    grid=True
)

# Display plot
violent_crimes_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [year]   (value)

# %%
# Show only total violent crimes
total_violent_crimes = crime_rates_df[['total_violent']]
total_violent_crimes.head()
# Out:
#       total_violent
# year
# 1960        0.28846
# 1961        0.28939
# 1962        0.30151
# 1963        0.31697
# 1964        0.36422

# %%
# Create visual for total violent crimes
total_violent_crimes = total_violent_crimes.hvplot.line(
    title="Total Violent Crimes 1960-2014",
    x ='year',
    xlabel="Year",
    ylabel="Number of Crimes (in Millions)",
    width=1000,
    height=400,
    grid=True
)

#Display plot
total_violent_crimes
# Out:
# :Curve   [year]   (total_violent)

# %%
# Plot total non-violent and violent crimes
total_crimes = crime_rates_df[["total_violent", "total_nonviolent"]]
total_crimes.head()
# Out:
#       total_violent  total_nonviolent
# year
# 1960        0.28846            3.0957
# 1961        0.28939            3.1986
# 1962        0.30151            3.4507
# 1963        0.31697            3.7925
# 1964        0.36422            4.2004

# %%
# Plot total crimes
total_crimes_plot = total_crimes.hvplot(
    title="Total Violent vs Non-Violent Crimes 1960-2014",
    x ='year',
    xlabel="Year",
    ylabel="Number of Crimes (in Millions)",
    width=1000,
    height=400,
    grid=True   
)

#Display plot
total_crimes_plot
# Out:
# :NdOverlay   [Variable]
#    :Curve   [year]   (value)

# %% [markdown]
# Using Prophet for forecasting total nonviolent crimes

# %%
# Create new dataframe from non violent crimes
total_nonviolent_trends = total_crimes["total_nonviolent"].to_frame()

# Display head and tail
display(total_nonviolent_trends.head())
display(total_nonviolent_trends.tail())
# Out:
#       total_nonviolent
# year
# 1960            3.0957
# 1961            3.1986
# 1962            3.4507
# 1963            3.7925
# 1964            4.2004
#       total_nonviolent
# year
# 2010          9.112625
# 2011          9.052743
# 2012          9.001992
# 2013          8.650761
# 2014          8.277829

# %%
# Reset the index
total_nonviolent_trends.reset_index(inplace=True)

# Label the columns for Prophet
total_nonviolent_trends.columns = ["ds", "y"]

# Display dtype
total_nonviolent_trends.dtypes
# Out:
# ds      int64
# y     float64
# dtype: object

# %%
# Tranlate year object to date time using last day of year for year data
total_nonviolent_trends["ds"] = pd.to_datetime(total_nonviolent_trends["ds"], format="%Y")

# Display dtype
total_nonviolent_trends.dtypes

# Display head and tail
display(total_nonviolent_trends.head())
display(total_nonviolent_trends.tail())
# Out:
#           ds       y
# 0 1960-01-01  3.0957
# 1 1961-01-01  3.1986
# 2 1962-01-01  3.4507
# 3 1963-01-01  3.7925
# 4 1964-01-01  4.2004
#            ds         y
# 50 2010-01-01  9.112625
# 51 2011-01-01  9.052743
# 52 2012-01-01  9.001992
# 53 2013-01-01  8.650761
# 54 2014-01-01  8.277829

# %%
# Adjust date to last day of year
total_nonviolent_trends["ds"] = total_nonviolent_trends["ds"].apply(lambda x: x.replace(month=12, day=31))

# Display head and tail
display(total_nonviolent_trends.head())
display(total_nonviolent_trends.tail())
# Out:
#           ds       y
# 0 1960-12-31  3.0957
# 1 1961-12-31  3.1986
# 2 1962-12-31  3.4507
# 3 1963-12-31  3.7925
# 4 1964-12-31  4.2004
#            ds         y
# 50 2010-12-31  9.112625
# 51 2011-12-31  9.052743
# 52 2012-12-31  9.001992
# 53 2013-12-31  8.650761
# 54 2014-12-31  8.277829

# %%
# Call the Prophet function, store as an object
total_nonviolent_m = Prophet()
total_nonviolent_m

# %%
# Fit the time-series model.
total_nonviolent_m.fit(total_nonviolent_trends)
# Out:
# 19:31:08 - cmdstanpy - INFO - Chain [1] start processing
# 19:31:08 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create a future dataframe to hold predictions
# Make the prediction go out as far as 20 years
future_total_nonviolent_trends = total_nonviolent_m.make_future_dataframe(periods=20, freq="Y")

# View the last five rows of the future_inflation_trends DataFrame
future_total_nonviolent_trends.tail()
# Out:
#            ds
# 70 2030-12-31
# 71 2031-12-31
# 72 2032-12-31
# 73 2033-12-31
# 74 2034-12-31

# %%
# Make the predictions for the trend data using the future_total_nonviolent_trends DataFrame
forecast_total_nonviolent_trends = total_nonviolent_m.predict(future_total_nonviolent_trends)

# Display the head and tail of forecast_total_nonviolent_trends DataFrame
display(forecast_total_nonviolent_trends.head())
display(forecast_total_nonviolent_trends.tail())
# Out:
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1960-12-31  2.604326    2.187942    3.284396     2.604326     2.604326
# 1 1961-12-31  3.039222    2.608367    3.695011     3.039222     3.039222
# 2 1962-12-31  3.474119    3.020794    4.076431     3.474119     3.474119
# 3 1963-12-31  3.909015    3.518336    4.594807     3.909015     3.909015
# 4 1964-12-31  4.345103    3.945586    4.990396     4.345103     4.345103
#
#    additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0        0.144244              0.144244              0.144244  0.144244
# 1        0.088196              0.088196              0.088196  0.088196
# 2        0.084626              0.084626              0.084626  0.084626
# 3        0.133530              0.133530              0.133530  0.133530
# 4        0.144244              0.144244              0.144244  0.144244
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0      0.144244      0.144244                   0.0
# 1      0.088196      0.088196                   0.0
# 2      0.084626      0.084626                   0.0
# 3      0.133530      0.133530                   0.0
# 4      0.144244      0.144244                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0
# 53 2013-12-31   8.650761
# 54 2014-12-31   8.277829

# %%
# Create trends for last 30 years
total_nonviolent_trends_30 = total_nonviolent_trends.iloc[24:,:]

# Display trends
total_nonviolent_trends_30
# Out:
#            ds          y
# 24 1984-12-31  10.608500
# 25 1985-12-31  11.102600
# 26 1986-12-31  11.722700
# 27 1987-12-31  12.024700
# 28 1988-12-31  12.356900
# 29 1989-12-31  12.605400
# 30 1990-12-31  12.655500
# 31 1991-12-31  12.961100
# 32 1992-12-31  12.505900
# 33 1993-12-31  12.218800
# 34 1994-12-31  12.131900
# 35 1995-12-31  12.063900
# 36 1996-12-31  11.805300
# 37 1997-12-31  11.558175
# 38 1998-12-31  10.944590
# 39 1999-12-31  10.208334
# 40 2000-12-31  10.182586
# 41 2001-12-31  10.437480
# 42 2002-12-31  10.455277
# 43 2003-12-31  10.442862
# 44 2004-12-31  10.319386
# 45 2005-12-31  10.174754
# 46 2006-12-31   9.983568
# 47 2007-12-31   9.843481
# 48 2008-12-31   9.767915
# 49 2009-12-31   9.337060
# 50 2010-12-31   9.112625
# 51 2011-12-31   9.052743
# 52 2012-12-31   9.001992
# 53 2013-12-31   8.650761
# 54 2014-12-31   8.277829

# %%
# Call the Prophet function, store as an object
total_nonviolent_trends_30_m = Prophet()
total_nonviolent_trends_30_m

# %%
# Fit the time-series model.
total_nonviolent_trends_30_m.fit(total_nonviolent_trends_30)
# Out:
# 19:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 19:31:09 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create a future dataframe to hold predictions
# Make the prediction go out as far as 20 years
future_total_nonviolent_trends_30 = total_nonviolent_trends_30_m.make_future_dataframe(periods=20, freq="Y")

# View the last five rows of the future_inflation_trends DataFrame
future_total_nonviolent_trends_30.tail()
# Out:
#            ds
# 46 2030-12-31
# 47 2031-12-31
# 48 2032-12-31
# 49 2033-12-31
# 50 2034-12-31

# %%
# Make the predictions for the trend data using the future_inflation_trends DataFrame
forecast_total_nonviolent_trends_30 = total_nonviolent_trends_30_m.predict(future_total_nonviolent_trends_30)

# Display the head and tail of forecast_inflation_trends DataFrame
display(forecast_total_nonviolent_trends_30.head())
display(forecast_total_nonviolent_trends_30.tail())
# Out:
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1984-12-31  0.855366   10.953011   11.766463     0.855366     0.855366
# 1 1985-12-31  1.010746   11.110446   11.968471     1.010746     1.010746
# 2 1986-12-31  1.166125   11.286471   12.143492     1.166125     1.166125
# 3 1987-12-31  1.321505   11.471762   12.321470     1.321505     1.321505
# 4 1988-12-31  1.477307   11.567199   12.399869     1.477307     1.477307
#
#    additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0       10.512791             10.512791             10.512791  10.512791
# 1       10.529480             10.529480             10.529480  10.529480
# 2       10.550725             10.550725             10.550725  10.550725
# 3       10.576514             10.576514             10.576514  10.576514
# 4       10.512791             10.512791             10.512791  10.512791
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0     10.512791     10.512791                   0.0
# 1     10.529480     10.529480                   0.0
# 2     10.550725     10.550725                   0.0
# 3     10.576514     10.576514                   0.0
# 4     10.512791     10.512791                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 0                         0.0                         0.0  11.368158
# 1                         0.0                         0.0  11.540226
# 2                         0.0                         0.0  11.716851
# 3                         0.0                         0.0  11.898019
# 4                         0.0                         0.0  11.990098
#            ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 46 2030-12-31 -4.858189    4.731591    6.669200    -5.704020    -4.005790
# 47 2031-12-31 -5.032427    4.618876    6.540618    -5.952066    -4.095668
# 48 2032-12-31 -5.207142    4.244137    6.427265    -6.221879    -4.198765
# 49 2033-12-31 -5.381380    3.956903    6.347444    -6.491521    -4.289553
# 50 2034-12-31 -5.555618    3.772878    6.274430    -6.760534    -4.361949
#
#     additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 46       10.550725             10.550725             10.550725  10.550725
# 47       10.576514             10.576514             10.576514  10.576514
# 48       10.512791             10.512791             10.512791  10.512791
# 49       10.529480             10.529480             10.529480  10.529480
# 50       10.550725             10.550725             10.550725  10.550725
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 46     10.550725     10.550725                   0.0
# 47     10.576514     10.576514                   0.0
# 48     10.512791     10.512791                   0.0
# 49     10.529480     10.529480                   0.0
# 50     10.550725     10.550725                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 46                         0.0                         0.0  5.692536
# 47                         0.0                         0.0  5.544087
# 48                         0.0                         0.0  5.305649
# 49                         0.0                         0.0  5.148100
# 50                         0.0                         0.0  4.995108

# %%
# Plot the Prophet predictions for the inflation trends data

# Added ; to prevent 2 plots from displaying

total_nonviolent_trends_30_m.plot(forecast_total_nonviolent_trends_30);

# %% [markdown]
# Summary

# %% [markdown]
# Using Prophet for forecasting total violent crimes

# %%
# Create new dataframe from violent crimes
total_violent_trends = total_crimes["total_violent"].to_frame()

# Display head and tail
display(total_violent_trends.head())
display(total_violent_trends.tail())
# Out:
#       total_violent
# year
# 1960        0.28846
# 1961        0.28939
# 1962        0.30151
# 1963        0.31697
# 1964        0.36422
#       total_violent
# year
# 2010       1.251248
# 2011       1.206031
# 2012       1.217067
# 2013       1.199684
# 2014       1.197987

# %%
# Reset the index
total_violent_trends.reset_index(inplace=True)

# Label the columns for Prophet
total_violent_trends.columns = ["ds", "y"]

# Display dtype
total_violent_trends.dtypes
# Out:
# ds      int64
# y     float64
# dtype: object

# %%
# Tranlate year object to date time using last day of year for year data
total_violent_trends["ds"] = pd.to_datetime(total_violent_trends["ds"], format="%Y")

# Display dtype
total_violent_trends.dtypes

# Display head and tail
display(total_violent_trends.head())
display(total_violent_trends.tail())
# Out:
#           ds        y
# 0 1960-01-01  0.28846
# 1 1961-01-01  0.28939
# 2 1962-01-01  0.30151
# 3 1963-01-01  0.31697
# 4 1964-01-01  0.36422
#            ds         y
# 50 2010-01-01  1.251248
# 51 2011-01-01  1.206031
# 52 2012-01-01  1.217067
# 53 2013-01-01  1.199684
# 54 2014-01-01  1.197987

# %%
# Adjust date to last day of year
total_violent_trends["ds"] = total_violent_trends["ds"].apply(lambda x: x.replace(month=12, day=31))

# Display head and tail
display(total_violent_trends.head())
display(total_violent_trends.tail())
# Out:
#           ds        y
# 0 1960-12-31  0.28846
# 1 1961-12-31  0.28939
# 2 1962-12-31  0.30151
# 3 1963-12-31  0.31697
# 4 1964-12-31  0.36422
#            ds         y
# 50 2010-12-31  1.251248
# 51 2011-12-31  1.206031
# 52 2012-12-31  1.217067
# 53 2013-12-31  1.199684
# 54 2014-12-31  1.197987

# %%
# Call the Prophet function, store as an object
total_violent_m = Prophet()
total_violent_m

# %%
# Fit the time-series model.
total_violent_m.fit(total_violent_trends)
# Out:
# 19:31:09 - cmdstanpy - INFO - Chain [1] start processing
# 19:31:09 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Create a future dataframe to hold predictions
# Make the prediction go out as far as 20 years
future_total_violent_trends = total_violent_m.make_future_dataframe(periods=20, freq="Y")

# View the last five rows 
future_total_violent_trends.tail()
# Out:
#            ds
# 70 2030-12-31
# 71 2031-12-31
# 72 2032-12-31
# 73 2033-12-31
# 74 2034-12-31

# %%
# Make the predictions for the trend data 
forecast_total_violent_trends = total_violent_m.predict(future_total_violent_trends)

# Display the head and tail 
display(forecast_total_violent_trends.head())
display(forecast_total_violent_trends.tail())
# Out:
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1960-12-31  0.149017    0.234663    1.020739     0.149017     0.149017
# 1 1961-12-31  0.169615    0.218061    1.085100     0.169615     0.169615
# 2 1962-12-31  0.190213    0.261506    1.074471     0.190213     0.190213
# 3 1963-12-31  0.210812    0.344118    1.116185     0.210812     0.210812
# 4 1964-12-31  0.231466    0.259240    1.118954     0.231466     0.231466
#
#    additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0        0.473032              0.473032              0.473032  0.473032
# 1        0.479303              0.479303              0.479303  0.479303
# 2        0.487994              0.487994              0.487994  0.487994
# 3        0.499095              0.499095              0.499095  0.499095
# 4        0.473032              0.473032              0.473032  0.473032
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0      0.473032      0.473032                   0.0
# 1      0.479303      0.479303                   0.0
# 2      0.487994      0.487994                   0.0
# 3      0.499095      0.499095                   0.0
# 4      0.473032      0.473032                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  0.622049
# 1                         0.0                         0.0  0.648918
# 2                         0.0                         0.0  0.678208
# 3                         0.0                         0.0  0.709907
# 4                         0.0                         0.0  0.704498
#            ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 70 2030-12-31  1.583470    1.669246    2.510189     1.583113     1.583861
# 71 2031-12-31  1.603863    1.726757    2.462388     1.603475     1.604297
# 72 2032-12-31  1.624313    1.705597    2.475932     1.623889     1.624791
# 73 2033-12-31  1.644706    1.736170    2.541433     1.644243     1.645226
# 74 2034-12-31  1.665099    1.760548    2.560229     1.664608     1.665656
#
#     additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 70        0.487994              0.487994              0.487994  0.487994
# 71        0.499095              0.499095              0.499095  0.499095
# 72        0.473032              0.473032              0.473032  0.473032
# 73        0.479303              0.479303              0.479303  0.479303
# 74        0.487994              0.487994              0.487994  0.487994
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 70      0.487994      0.487994                   0.0
# 71      0.499095      0.499095                   0.0
# 72      0.473032      0.473032                   0.0
# 73      0.479303      0.479303                   0.0
# 74      0.487994      0.487994                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 70                         0.0                         0.0  2.071465
# 71                         0.0                         0.0  2.102959
# 72                         0.0                         0.0  2.097345
# 73                         0.0                         0.0  2.124009
# 74                         0.0                         0.0  2.153094

# %%
# Plot the Prophet predictions

# Added ; to prevent 2 plots from displaying

total_violent_m.plot(forecast_total_violent_trends);

# %% [markdown]
# Summary

# %%
# Show violent trends
total_violent_trends
# Out:
#            ds         y
# 0  1960-12-31  0.288460
# 1  1961-12-31  0.289390
# 2  1962-12-31  0.301510
# 3  1963-12-31  0.316970
# 4  1964-12-31  0.364220
# 5  1965-12-31  0.387390
- cmdstanpy - INFO - Chain [1] done processing

# %%
# Create a future dataframe to hold predictions
# Make the prediction go out as far as 20 years
future_total_violent_trends_30 = total_violent_trends_30_m.make_future_dataframe(periods=20, freq="Y")

# View the last five rows of the future_inflation_trends DataFrame
future_total_violent_trends_30.tail()
# Out:
#            ds
# 46 2030-12-31
# 47 2031-12-31
# 48 2032-12-31
# 49 2033-12-31
# 50 2034-12-31

# %%
# Make the predictions for the trend data using the future_inflation_trends DataFrame
forecast_total_violent_trends_30 = total_violent_trends_30_m.predict(future_total_violent_trends_30)

# Display the head and tail of forecast_inflation_trends DataFrame
display(forecast_total_violent_trends_30.head())
display(forecast_total_violent_trends_30.tail())
# Out:
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 1984-12-31 -0.035985    1.458751    1.935901    -0.035985    -0.035985
# 1 1985-12-31 -0.050828    1.461830    1.932655    -0.050828    -0.050828
# 2 1986-12-31 -0.065672    1.471791    1.919324    -0.065672    -0.065672
# 3 1987-12-31 -0.080515    1.476624    1.932956    -0.080515    -0.080515
# 4 1988-12-31 -0.095400    1.411926    1.855559    -0.095400    -0.095400
#
#    additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0        1.727151              1.727151              1.727151  1.727151
# 1        1.747825              1.747825              1.747825  1.747825
# 2        1.765648              1.765648              1.765648  1.765648
# 3        1.780596              1.780596              1.780596  1.780596
# 4        1.727151              1.727151              1.727151  1.727151
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0      1.727151      1.727151                   0.0
# 1      1.747825      1.747825                   0.0
# 2      1.765648      1.765648                   0.0
# 3      1.780596      1.780596                   0.0
# 4      1.727151      1.727151                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  1.691166
# 1                         0.0                         0.0  1.696997
# 2                         0.0                         0.0  1.699976
# 3                         0.0                         0.0  1.700081
# 4                         0.0                         0.0  1.631751
#            ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 46 2030-12-31 -0.721385    0.822768    1.298960    -0.721533    -0.721239
# 47 2031-12-31 -0.736288    0.804641    1.270850    -0.736450    -0.736126
# 48 2032-12-31 -0.751231    0.738930    1.215079    -0.751409    -0.751053
# 49 2033-12-31 -0.766133    0.755712    1.206144    -0.766327    -0.765939
# 50 2034-12-31 -0.781036    0.751831    1.207549    -0.781245    -0.780830
#
#     additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 46        1.765648              1.765648              1.765648  1.765648
# 47        1.780596              1.780596              1.780596  1.780596
# 48        1.727151              1.727151              1.727151  1.727151
# 49        1.747825              1.747825              1.747825  1.747825
# 50        1.765648              1.765648              1.765648  1.765648
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 46      1.765648      1.765648                   0.0
# 47      1.780596      1.780596                   0.0
# 48      1.727151      1.727151                   0.0
# 49      1.747825      1.747825                   0.0
# 50      1.765648      1.765648                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 46                         0.0                         0.0  1.044262
# 47                         0.0                         0.0  1.044309
# 48                         0.0                         0.0  0.975920
# 49                         0.0                         0.0  0.981692
# 50                         0.0                         0.0  0.984612

# %%
# Plot the Prophet predictions for the inflation trends data

# Added ; to prevent 2 plots from displaying

total_violent_trends_30_m.plot(forecast_total_violent_trends_30);

# %% [markdown]
# Simple Model

# %%
total_violent_trends
# Out:
#            ds         y
# 0  1960-12-31  0.288460
# 1  1961-12-31  0.289390
# 2  1962-12-31  0.301510
# 3  1963-12-31  0.316970
# 4  1964-12-31  0.364220
# 5  1965-12-31  0.387390
# 6  1966-12-31  0.430180
# 7  1967-12-31  0.499930
# 8  1968-12-31  0.595010
# 9  1969-12-31  0.661870
# 2008-12-31  1.392628
# 2009-12-31  1.325896
# 2010-12-31  1.251248
# 2011-12-31  1.206031
# 2012-12-31  1.217067
# 2013-12-31  1.199684
# 2014-12-31  1.197987

# %%
violent = simple_model_violent["violent"]
train = violent.iloc[:-5]
test = violent.iloc[-5:]

# %%
rooted = np.sqrt(violent)
diffed = rooted.diff(1)
diffed_s = diffed.diff(4).dropna()
plt.figure(figsize=(10,5))
plt.plot(diffed_s,color="blue",label="Violent")
plt.legend()
plt.margins(x=0)
plt.grid(alpha=0.5)

# %%
full_sample = []
np.random.seed(50)
for i in range(10000):
    draw = np.random.choice(diffed_s,len(test))
    result = list(diffed.iloc[-12:].values)
    for t in range(len(test)):
        result.append(result[t]+draw[t])
    full_sample.append(np.array(((rooted.iloc[-1])+np.cumsum(result[12:]))**2).reshape(-1,1))
reshaped = np.concatenate(full_sample,1)
result_mean = np.mean(reshaped,1)
lower = np.quantile(reshaped,0.05,1)
upper = np.quantile(reshaped,0.95,1)
plt.figure(figsize = (16,8))
plt.plot(train, label = "Train",color="blue")
plt.plot(test, label = "Test",color="red")
plt.grid(alpha = 0.5)
plt.plot(test.index, result_mean,label = "Simple model forecast",color="green")
plt.legend()
plt.fill_between(test.index,lower,upper,alpha=0.3,color="green");

# %%
total_nonviolent_trends
# Out:
#            ds          y
# 0  1960-12-31   3.095700
# 1  1961-12-31   3.198600
# 2  1962-12-31   3.450700
# 3  1963-12-31   3.792500
# 4  1964-12-31   4.200400
# 5  1965-12-31   4.352000
# 6  1966-12-31   4.793300
# 7  1967-12-31   5.403500
# 8  1968-12-31   6.125200
# 9  1969-12-31   6.749000
# 10 1970-12-31   7.359200
# 11 1971-12-31   7.771700
# 12 1972-12-31   7.413900
# 13 1973-12-31   7.842200
# 14 1974-12-31   9.278700
# 15 1975-12-31  10.252700
# 16 1976-12-31  10.345500
# 17 1977-12-31   9.955000
# 18 1978-12-31  10.123400
# 19 1979-12-31  11.041500
# 20 1980-12-31  12.063700
# 21 1981-12-31  12.061900
# 22 1982-12-31  11.652000
# 23 1983-12-31  10.850500
# 24 1984-12-31  10.608500
# 25 1985-12-31  11.102600
# 26 1986-12-31  11.722700
# 27 1987-12-31  12.024700
# 28 1988-12-31  12.356900
# 29 1989-12-31  12.605400
# 30 1990-12-31  12.655500
# 31 1991-12-31  12.961100
# 32 1992-12-31  12.505900
# 33 1993-12-31  12.218800
# 34 1994-12-31  12.131900
# 35 1995-12-31  12.063900
# 36 1996-12-31  11.805300
# 37 1997-12-31  11.558175
# 38 1998-12-31  10.944590
# 39 1999-12-31  10.208334
# 40 2000-12-31  10.182586
# 41 2001-12-31  10.437480
# 42 2002-12-31  10.455277
# 43 2003-12-31  10.442862
# 44 2004-12-31  10.319386
# 45 2005-12-31  10.174754
# 46 2006-12-31   9.983568
# 47 2007-12-31   9.843481
# 48 2008-12-31   9.767915
# 49 2009-12-31   9.337060
# 50 2010-12-31   9.112625
# 51 2011-12-31   9.052743
# 52 2012-12-31   9.001992
# 53 2013-12-31   8.650761
# 54 2014-12-31   8.277829

# %%
simple_model_nonviolent = total_nonviolent_trends.copy()
simple_model_nonviolent.rename(columns={"ds": "year", "y": "nonviolent"}, inplace=True)
simple_model_nonviolent.set_index("year", inplace=True)
simple_model_nonviolent
# Out:
#             nonviolent
# year
# 1960-12-31    3.095700
# 1961-12-31    3.198600
# 1962-12-31    3.450700
# 1963-12-31    3.792500
# 1964-12-31    4.200400
# 1965-12-31    4.352000
# 1966-12-31    4.793300
# 1967-12-31    5.403500
# 1968-12-31    6.125200
# 1969-12-31    6.749000
# 1970-12-31    7.359200
# 1971-12-31    7.771700
# 1972-12-31    7.413900
# 1973-12-31    7.842200
# 1974-12-31    9.278700
# 1975-12-31   10.252700
# 1976-12-31   10.345500
# 1977-12-31    9.955000
# 1978-12-31   10.123400
# 1979-12-31   11.041500
# 1980-12-31   12.063700
# 1981-12-31   12.061900
# 1982-12-31   11.652000
# 1983-12-31   10.850500
# 1984-12-31   10.608500
# 1985-12-31   11.102600
# 1986-12-31   11.722700
# 1987-12-31   12.024700
# 1988-12-31   12.356900
# 1989-12-31   12.605400
# 1990-12-31   12.655500
# 1991-12-31   12.961100
# 1992-12-31   12.505900
# 1993-12-31   12.218800
# 1994-12-31   12.131900
# 1995-12-31   12.063900
# 1996-12-31   11.805300
# 1997-12-31   11.558175
# 1998-12-31   10.944590
# 1999-12-31   10.208334
# 2000-12-31   10.182586
# 2001-12-31   10.437480
# 2002-12-31   10.455277
# 2003-12-31   10.442862
# 2004-12-31   10.319386
# 2005-12-31   10.174754
# 2006-12-31    9.983568
# 2007-12-31    9.843481
# 2008-12-31    9.767915
# 2009-12-31    9.337060
# 2010-12-31    9.112625
# 2011-12-31    9.052743
# 2012-12-31    9.001992
# 2013-12-31    8.650761
# 2014-12-31    8.277829

# %%
nonviolent = simple_model_nonviolent["nonviolent"]
train = nonviolent.iloc[:-5]
test = nonviolent.iloc[-5:]

# %%
rooted = np.sqrt(nonviolent)
diffed = rooted.diff(1)
diffed_s = diffed.diff(4).dropna()
plt.figure(figsize=(10,5))
plt.plot(diffed_s,color="blue",label="Nonviolent")
plt.legend()
plt.margins(x=0)
plt.grid(alpha=0.5)

# %%
full_sample = []
np.random.seed(50)
for i in range(10000):
    draw = np.random.choice(diffed_s,len(test))
    result = list(diffed.iloc[-12:].values)
    for t in range(len(test)):
        result.append(result[t]+draw[t])
    full_sample.append(np.array(((rooted.iloc[-1])+np.cumsum(result[12:]))**2).reshape(-1,1))
reshaped = np.concatenate(full_sample,1)
result_mean = np.mean(reshaped,1)
lower = np.quantile(reshaped,0.05,1)
upper = np.quantile(reshaped,0.95,1)
plt.figure(figsize = (10,5))
plt.plot(train, label = "Train",color="blue")
plt.plot(test, label = "Test",color="red")
plt.grid(alpha = 0.5)
plt.plot(test.index, result_mean,label = "Simple model forecast",color="green")
plt.legend()
plt.fill_between(test.index,lower,upper,alpha=0.3,color="green");
